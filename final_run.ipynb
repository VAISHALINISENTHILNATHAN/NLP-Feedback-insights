# %%
from src.preprocessing import preprocess_file
preprocess_file()

# %%
from src.sentiment import run_sentiment
run_sentiment()

# %%
from src.topic_modeling import run_topic_modeling
run_topic_modeling()

# %%
pip install umap-learn hdbscan

# %%
pip install scikit-learn==1.2.2

# %%
# Upgrade pip first
# %pip install --upgrade pip

# Core libraries
# %pip install pandas numpy scikit-learn==1.2.2 ipywidgets --prefer-binary

# NLP and Transformers
# %pip install nltk transformers torch --prefer-binary

# Topic Modeling
# %pip install bertopic hdbscan umap-learn --prefer-binary

# Streamlit for dashboard
# %pip install streamlit --prefer-binary

# Hugging Face utilities
# %pip install huggingface_hub[hf_xet] --prefer-binary
